# %% [markdown]
# # 時系列データ
# 1. 表形式のデータとは異なり、行方向に時間情報がついたようなデータ形式。
# 2. 気温の変化、株価の変化、経済成長、流行・ブームなど、時間とともに変化するデータが対象
# 3. 一般に折れ線グラフで可視化する
#
#    例：気象庁の過去の気温データ
#    https://www.data.jma.go.jp/risk/obsdl/index.php

# %%
import pandas as pd
temp_series = pd.read_csv('temprature_series.csv',encoding='ms932', sep=',',skiprows=0  , parse_dates=['年月日'])
temp_series
# Out:
#             年月日  東京平均気温  東京最高気温  さいたま平均気温  さいたま最高気温  熊谷平均気温  熊谷最高気温  前橋平均気温  \
# 0    2010-01-01     4.8     9.5       2.4       8.4     3.0     7.8     1.5
# 1    2010-01-02     6.3    11.4       4.1      11.4     5.4    11.4     3.7
# 2    2010-01-03     5.7     9.2       3.2       9.4     3.4    10.5     3.5
# 3    2010-01-04     6.5     9.6       3.8       8.8     4.4     9.5     3.5
# 4    2010-01-05     7.3    13.2       5.2      13.4     5.3    13.3     4.8
# ...         ...     ...     ...       ...       ...     ...     ...     ...
# 5308 2024-07-14    25.4    28.8      24.9      27.1    23.8    25.0    23.9
# 5309 2024-07-15    24.6    27.7      24.3      27.3    24.2    27.1    24.0
# 5310 2024-07-16    23.9    27.3      23.7      26.2    22.9    24.3    22.1
# 5311 2024-07-17    25.8    31.3      26.4      32.3    26.4    31.6    26.3
# 5312 2024-07-18    28.4    33.4      28.8      34.5    28.4    33.6    28.3
#
#       前橋最高気温  沼田平均気温  沼田最高気温
# 0        6.8    -1.9     0.7
# 1        9.4     0.5     5.0
# 2        8.1     0.1     4.1
# 3        9.5     0.8     5.8
# 4       11.5     0.7     5.8
# ...      ...     ...     ...
# 5308    25.6    22.6    26.9
# 5309    26.2    22.4    25.5
# 5310    23.5    20.8    21.9
# 5311    31.6    23.3    29.4
# 5312    33.3    25.0    32.6
#
# [5313 rows x 11 columns]

# %% [markdown]
# ## 東京の2010~2024の日次平均気温の時系列

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import japanize_matplotlib

figure(figsize=(14, 6))
sns.lineplot(data=temp_series,x='年月日',y='東京平均気温')
plt.xticks(rotation=45,ha='right')
# Out:
# (array([13879., 14610., 15340., 16071., 16801., 17532., 18262., 18993.,
#         19723., 20454.]),
#  [Text(13879.0, 0, '2008'),
#   Text(14610.0, 0, '2010'),
#   Text(15340.0, 0, '2012'),
#   Text(16071.0, 0, '2014'),
#   Text(16801.0, 0, '2016'),
#   Text(17532.0, 0, '2018'),
#   Text(18262.0, 0, '2020'),
#   Text(18993.0, 0, '2022'),
#   Text(19723.0, 0, '2024'),
#   Text(20454.0, 0, '2026')])

# %% [markdown]
# # 時系列データのためのデータ型：datetime型(timedelta型を含む）
# 1. 日付の演算ができる。例えば20220720の1か月後と20220620の1か月後は、大小の月を加味する必要がある
# 2. timezoneの変換（つまり時差の自動計算）
# 3. 大小比較、ソート（2022-12-1 と 2022-1-31 の大小関係など、表示形式によって大小比較が難しい場合がある）
# 4. いろいろな表示形式の編集　2022/7/30 -> 20220730 とか
#
# 参考リンク　 https://python.softmoco.com/basics/python-datetime.php

# %% [markdown]
# # 1. datetime型の演算

# %% [markdown]
# **例1. 時刻の和差の計算**
# https://qiita.com/dkugi/items/8c32cc481b365c277ec2
# - datatime型の日付の和・差を計算するだけで計算ができる
# - 数値型として日付の演算をするとかなり面倒

# %%
import datetime
print(datetime.date(2025, 9, 15))
# Out:
# 2025-09-15

# %%
date1 = datetime.date(2024, 10, 15)
date2 = datetime.date(2024, 7, 15)
print(date1 - date2)
# Out:
# 92 days, 0:00:00

# %%
date2 + datetime.timedelta(days=92)
# Out:
# datetime.date(2024, 10, 15)

# %%
date2 + datetime.timedelta(weeks=13)
# Out:
# datetime.date(2024, 10, 14)

# %%
from dateutil.relativedelta import relativedelta
data2 + relativedelta(months=3)
# Out:
# datetime.date(2024, 10, 15)

# %% [markdown]
# **例2. 日付の配列を作る**
# https://note.nkmk.me/python-datetime-usage/

# %%
date3 = datetime.date(2024, 7, 1)
d = datetime.timedelta(days=1)
n = 10
l = [(date3 + i * d) for i in range(n)]
print(l)
# Out:
# [datetime.date(2024, 7, 1), datetime.date(2024, 7, 2), datetime.date(2024, 7, 3), datetime.date(2024, 7, 4), datetime.date(2024, 7, 5), datetime.date(2024, 7, 6), datetime.date(2024, 7, 7), datetime.date(2024, 7, 8), datetime.date(2024, 7, 9), datetime.date(2024, 7, 10)]

# %%
w = datetime.timedelta(weeks=2)
n = 4
l = [(date3 + i * w) for i in range(n)]
print(l)
# Out:
# [datetime.date(2024, 7, 1), datetime.date(2024, 7, 15), datetime.date(2024, 7, 29), datetime.date(2024, 8, 12)]

# %% [markdown]
# **例3. 秒単位での計算もできる**

# %%
ymdhms1 = datetime.datetime(2024, 10, 15, 14, 35, 22)
ymdhms2 = datetime.datetime(2024, 7, 15, 20, 1, 10)
ymdhms1 - ymdhms2
# Out:
# datetime.timedelta(days=91, seconds=66852)

# %% [markdown]
# # 演習1. 日付の配列を作る
# 1. 2024.7.24から１ヵ月毎に1年後までの配列を、上記　例2にならって作成せよ
# 2. この配列から、隣り合う日付間の日数を計算して配列にせよ

# %%
# Out:
# [datetime.date(2024, 7, 24), datetime.date(2024, 8, 24), datetime.date(2024, 9, 24), datetime.date(2024, 10, 24), datetime.date(2024, 11, 24), datetime.date(2024, 12, 24), datetime.date(2025, 1, 24), datetime.date(2025, 2, 24), datetime.date(2025, 3, 24), datetime.date(2025, 4, 24), datetime.date(2025, 5, 24), datetime.date(2025, 6, 24)]

# %%
days = [ l[i+1] - l[i] for i in range(11)]
days
# Out:
# [datetime.timedelta(days=31),
#  datetime.timedelta(days=31),
#  datetime.timedelta(days=30),
#  datetime.timedelta(days=31),
#  datetime.timedelta(days=30),
#  datetime.timedelta(days=31),
#  datetime.timedelta(days=31),
#  datetime.timedelta(days=28),
#  datetime.timedelta(days=31),
#  datetime.timedelta(days=30),
#  datetime.timedelta(days=31)]

# %% [markdown]
# # 2. 日付の表示形式を編集する

# %% [markdown]
# **例1. 年月だけを取り出す**

# %%
date2.year
# Out:
# 2024

# %%
date2.month
# Out:
# 7

# %%
datetime.date(date2.year,date2.month,1)
# Out:
# datetime.date(2024, 7, 1)

# %%
date2.day
# Out:
# 15

# %% [markdown]
# hour minutes second を取り出す

# %%
ymdhms2.time()
# Out:
# datetime.time(20, 1, 10)

# %% [markdown]
# **例2. datatime型を文字列に変換**
# - 文字列に変換する際に様々な表示形式にする
# - 曜日を表示することもできる
#
# ### 構文
# ---
#
# ```python
# datetime型変数.strftime(書式コード)
# ```
# 書式コードは以下を参照
# https://note.nkmk.me/python-datetime-usage/
#
# ---
#
# 文字列をdatetime型に変換することもできる。
# 参考：https://note.nkmk.me/python-datetime-usage/

# %%
date1 = datetime.date(2024, 10, 15)
print(data1.strftime('%Y/%m/%d'))
print(data1.strftime('%Y-%m-%d'))
print(data1.strftime('%y/%m/%d'))
print(data1.strftime('%A, %B %d, %Y'))
ymdhms1 = datetime.datetime(2024, 10, 15, 14, 35, 22)
print(ymdhms1.strftime('%Y/%m/%d %H:%M:%S.%f'))
# Out:
# 2024/10/15
# 2024-10-15
# 24/10/15
# Tuesday, October 15, 2024
# 2024/10/15 14:35:22.000000

# %% [markdown]
# # 演習2. 月日の表示
#
# 1. 2024.7.22を以下の２通りに表示せよ
# - 07月22日
# - July 22
#
# 2.上記07月22日は文字列。この月日だけで再びdatetime型に変換せよ。文字列→datetime型の変換は以下の「strptime(): 文字列から日付・時間への変換」を参照
#   https://note.nkmk.me/python-datetime-usage/

# %%
date10 = datetime.date(2024, 7, 22)
# Out:
# 07月22日
# July 22

# %%
# Out:
# 1900-07-22 00:00:00

# %% [markdown]
# # 3. DataFrame 時系列データを扱う
# DataFrame 時系列データとは、タイムスタンプの列がついたデータ。以下の手順え処理する
# 1. DataFrameのタイムスタンプ列をdatetime型に変換
# 2. datetime型をソート
# 3. 時系列データに演算処理を加える
#
# **例1. DataFrameのタイムスタンプ列をdatetime型にする**
# dataframeに読み込む際に、parse_dates=['年月日']のように指定すると、年月日の列が一括してdaetime型に変換される

# %%
import pandas as pd
temp_series = pd.read_csv('temprature_series.csv',encoding='ms932', sep=',',skiprows=0  , parse_dates=['年月日'])
temp_series
# Out:
#             年月日  東京平均気温  東京最高気温  さいたま平均気温  さいたま最高気温  熊谷平均気温  熊谷最高気温  前橋平均気温  \
# 0    2010-01-01     4.8     9.5       2.4       8.4     3.0     7.8     1.5
# 1    2010-01-02     6.3    11.4       4.1      11.4     5.4    11.4     3.7
# 2    2010-01-03     5.7     9.2       3.2       9.4     3.4    10.5     3.5
# 3    2010-01-04     6.5     9.6       3.8       8.8     4.4     9.5     3.5
# 4    2010-01-05     7.3    13.2       5.2      13.4     5.3    13.3     4.8
# ...         ...     ...     ...       ...       ...     ...     ...     ...
# 5308 2024-07-14    25.4    28.8      24.9      27.1    23.8    25.0    23.9
# 5309 2024-07-15    24.6    27.7      24.3      27.3    24.2    27.1    24.0
# 5310 2024-07-16    23.9    27.3      23.7      26.2    22.9    24.3    22.1
# 5311 2024-07-17    25.8    31.3      26.4      32.3    26.4    31.6    26.3
# 5312 2024-07-18    28.4    33.4      28.8      34.5    28.4    33.6    28.3
#
#       前橋最高気温  沼田平均気温  沼田最高気温
# 0        6.8    -1.9     0.7
# 1        9.4     0.5     5.0
# 2        8.1     0.1     4.1
# 3        9.5     0.8     5.8
# 4       11.5     0.7     5.8
# ...      ...     ...     ...
# 5308    25.6    22.6    26.9
# 5309    26.2    22.4    25.5
# 5310    23.5    20.8    21.9
# 5311    31.6    23.3    29.4
# 5312    33.3    25.0    32.6
#
# [5313 rows x 11 columns]

# %% [markdown]
# **確かにdatetime型になっている**

# %%
print(temp_series['年月日'][5]-temp_series['年月日'][0])
# Out:
# 5 days 00:00:00

# %% [markdown]
# **例1. (2)DataFrameを読み込んだ後でdatatime型に変換することもできる**
# https://qiita.com/odacoh/items/1c3f5b159c4ffd92665c

# %%
import pandas as pd
temp_series = pd.read_csv('temprature_series.csv',encoding='ms932', sep=',',skiprows=0 )
temp_series['年月日'] =  pd.to_datetime(temp_series['年月日'])
temp_series
# Out:
#             年月日  東京平均気温  東京最高気温  さいたま平均気温  さいたま最高気温  熊谷平均気温  熊谷最高気温  前橋平均気温  \
# 0    2010-01-01     4.8     9.5       2.4       8.4     3.0     7.8     1.5
# 1    2010-01-02     6.3    11.4       4.1      11.4     5.4    11.4     3.7
# 2    2010-01-03     5.7     9.2       3.2       9.4     3.4    10.5     3.5
# 3    2010-01-04     6.5     9.6       3.8       8.8     4.4     9.5     3.5
# 4    2010-01-05     7.3    13.2       5.2      13.4     5.3    13.3     4.8
# ...         ...     ...     ...       ...       ...     ...     ...     ...
# 5308 2024-07-14    25.4    28.8      24.9      27.1    23.8    25.0    23.9
# 5309 2024-07-15    24.6    27.7      24.3      27.3    24.2    27.1    24.0
# 5310 2024-07-16    23.9    27.3      23.7      26.2    22.9    24.3    22.1
# 5311 2024-07-17    25.8    31.3      26.4      32.3    26.4    31.6    26.3
# 5312 2024-07-18    28.4    33.4      28.8      34.5    28.4    33.6    28.3
#
#       前橋最高気温  沼田平均気温  沼田最高気温
# 0        6.8    -1.9     0.7
# 1        9.4     0.5     5.0
# 2        8.1     0.1     4.1
# 3        9.5     0.8     5.8
# 4       11.5     0.7     5.8
# ...      ...     ...     ...
# 5308    25.6    22.6    26.9
# 5309    26.2    22.4    25.5
# 5310    23.5    20.8    21.9
# 5311    31.6    23.3    29.4
# 5312    33.3    25.0    32.6
#
# [5313 rows x 11 columns]

# %% [markdown]
# **例2. 年月日の列を月に変換**

# %%
temp_series["年月"] = temp_series['年月日'].dt.to_period("M")

# %% [markdown]
# **例3. 年月日を年に変換**
# https://datatechlog.com/how_to_translate_yyyymmdd_to_yyyymm/

# %%
temp_series["年"] = temp_series['年月日'].dt.to_period("Y")
temp_series
# Out:
#             年月日  東京平均気温  東京最高気温  さいたま平均気温  さいたま最高気温  熊谷平均気温  熊谷最高気温  前橋平均気温  \
# 0    2010-01-01     4.8     9.5       2.4       8.4     3.0     7.8     1.5
# 1    2010-01-02     6.3    11.4       4.1      11.4     5.4    11.4     3.7
# 2    2010-01-03     5.7     9.2       3.2       9.4     3.4    10.5     3.5
# 3    2010-01-04     6.5     9.6       3.8       8.8     4.4     9.5     3.5
# 4    2010-01-05     7.3    13.2       5.2      13.4     5.3    13.3     4.8
# ...         ...     ...     ...       ...       ...     ...     ...     ...
# 5308 2024-07-14    25.4    28.8      24.9      27.1    23.8    25.0    23.9
# 5309 2024-07-15    24.6    27.7      24.3      27.3    24.2    27.1    24.0
# 5310 2024-07-16    23.9    27.3      23.7      26.2    22.9    24.3    22.1
# 5311 2024-07-17    25.8    31.3      26.4      32.3    26.4    31.6    26.3
# 5312 2024-07-18    28.4    33.4      28.8      34.5    28.4    33.6    28.3
#
#       前橋最高気温  沼田平均気温  沼田最高気温        月     年   東京移動平均気温       年月
# 0        6.8    -1.9     0.7  2010-01  2010        NaN  2010-01
# 1        9.4     0.5     5.0  2010-01  2010        NaN  2010-01
# 2        8.1     0.1     4.1  2010-01  2010        NaN  2010-01
# 3        9.5     0.8     5.8  2010-01  2010        NaN  2010-01
# 4       11.5     0.7     5.8  2010-01  2010        NaN  2010-01
# ...      ...     ...     ...      ...   ...        ...      ...
# 5308    25.6    22.6    26.9  2024-07  2024  17.503056  2024-07
# 5309    26.2    22.4    25.5  2024-07  2024  17.495833  2024-07
# 5310    23.5    20.8    21.9  2024-07  2024  17.486667  2024-07
# 5311    31.6    23.3    29.4  2024-07  2024  17.481389  2024-07
# 5312    33.3    25.0    32.6  2024-07  2024  17.481111  2024-07
#
# [5313 rows x 15 columns]

# %% [markdown]
# **例5. 日付のソート**

# %%
	
# 降順でソート
temp_sorted = temp_series.sort_values('年月日', ascending=False)
temp_sorted
# Out:
#             年月日  東京平均気温  東京最高気温  さいたま平均気温  さいたま最高気温  熊谷平均気温  熊谷最高気温  前橋平均気温  \
# 5312 2024-07-18    28.4    33.4      28.8      34.5    28.4    33.6    28.3
# 5311 2024-07-17    25.8    31.3      26.4      32.3    26.4    31.6    26.3
# 5310 2024-07-16    23.9    27.3      23.7      26.2    22.9    24.3    22.1
# 5309 2024-07-15    24.6    27.7      24.3      27.3    24.2    27.1    24.0
# 5308 2024-07-14    25.4    28.8      24.9      27.1    23.8    25.0    23.9
# ...         ...     ...     ...       ...       ...     ...     ...     ...
# 4    2010-01-05     7.3    13.2       5.2      13.4     5.3    13.3     4.8
# 3    2010-01-04     6.5     9.6       3.8       8.8     4.4     9.5     3.5
# 2    2010-01-03     5.7     9.2       3.2       9.4     3.4    10.5     3.5
# 1    2010-01-02     6.3    11.4       4.1      11.4     5.4    11.4     3.7
# 0    2010-01-01     4.8     9.5       2.4       8.4     3.0     7.8     1.5
#
#       前橋最高気温  沼田平均気温  沼田最高気温        月     年
# 5312    33.3    25.0    32.6  2024-07  2024
# 5311    31.6    23.3    29.4  2024-07  2024
# 5310    23.5    20.8    21.9  2024-07  2024
# 5309    26.2    22.4    25.5  2024-07  2024
# 5308    25.6    22.6    26.9  2024-07  2024
# ...      ...     ...     ...      ...   ...
# 4       11.5     0.7     5.8  2010-01  2010
# 3        9.5     0.8     5.8  2010-01  2010
# 2        8.1     0.1     4.1  2010-01  2010
# 1        9.4     0.5     5.0  2010-01  2010
# 0        6.8    -1.9     0.7  2010-01  2010
#
# [5313 rows x 13 columns]

# %% [markdown]
# **例6. 月でソートする**
# 年にかかわらず月でまとめられるので、例えば10年分の月毎の推移を分析できる

# %%
temp_sorted = temp_series.sort_values('月')
temp_sorted
# Out:
#             年月日  東京平均気温  東京最高気温  さいたま平均気温  さいたま最高気温  熊谷平均気温  熊谷最高気温  前橋平均気温  \
# 0    2010-01-01     4.8     9.5       2.4       8.4     3.0     7.8     1.5
# 30   2010-01-31     9.2    12.4       6.8      12.9     7.1    13.4     6.9
# 29   2010-01-30     8.9    13.0       5.8      13.2     7.1    14.6     6.4
# 28   2010-01-29     8.9    11.6       6.3      10.8     7.1    13.0     6.7
# 27   2010-01-28    12.2    15.5       7.3      14.3     7.9    15.2     8.5
# ...         ...     ...     ...       ...       ...     ...     ...     ...
# 5297 2024-07-03    27.7    33.3      27.3      34.3    27.4    34.0    27.3
# 5295 2024-07-01    26.3    29.4      26.6      29.2    26.2    28.9    26.5
# 5311 2024-07-17    25.8    31.3      26.4      32.3    26.4    31.6    26.3
# 5302 2024-07-08    30.9    36.0      32.1      38.6    31.5    36.5    30.5
# 5312 2024-07-18    28.4    33.4      28.8      34.5    28.4    33.6    28.3
#
#       前橋最高気温  沼田平均気温  沼田最高気温        月     年
# 0        6.8    -1.9     0.7  2010-01  2010
# 30      12.0     3.0     9.8  2010-01  2010
# 29      13.4     1.6     9.2  2010-01  2010
# 28      11.6     2.6     7.4  2010-01  2010
# 27      16.9     4.8    13.2  2010-01  2010
# ...      ...     ...     ...      ...   ...
# 5297    33.2    24.8    33.6  2024-07  2024
# 5295    30.5    23.5    28.6  2024-07  2024
# 5311    31.6    23.3    29.4  2024-07  2024
# 5302    34.6    26.5    33.8  2024-07  2024
# 5312    33.3    25.0    32.6  2024-07  2024
#
# [5313 rows x 13 columns]

# %% [markdown]
# **例7. 移動平均**
# rollingとwindowsサイズ
# https://www.yutaka-note.com/entry/pandas_rolling
# https://blog.since2020.jp/data_analysis/moving_average/
# https://note.nkmk.me/python-pandas-rolling/

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import japanize_matplotlib
fig,ax = plt.subplots(1, figsize=(14,6))

temp_series['東京移動平均気温'] = temp_series['東京平均気温'].rolling(360).mean()
temp_series['熊谷移動平均気温'] = temp_series['熊谷平均気温'].rolling(360).mean()

sns.lineplot(data=temp_series,x='年月日',y='東京移動平均気温',label = '東京',ax=ax)
sns.lineplot(data=temp_series,x='年月日',y='熊谷移動平均気温',label = '熊谷',ax=ax)
plt.xticks(rotation=45,ha='right')
# Out:
# (array([14610., 15340., 16071., 16801., 17532., 18262., 18993., 19723.,
#         20454.]),
#  [Text(14610.0, 0, '2010'),
#   Text(15340.0, 0, '2012'),
#   Text(16071.0, 0, '2014'),
#   Text(16801.0, 0, '2016'),
#   Text(17532.0, 0, '2018'),
#   Text(18262.0, 0, '2020'),
#   Text(18993.0, 0, '2022'),
#   Text(19723.0, 0, '2024'),
#   Text(20454.0, 0, '2026')])

# %% [markdown]
# # 演習3. 最高気温の推移を表示する
# 東京、熊谷それぞれの最高気温をもとに、360日の移動最大値 max()を表示せよ

# %%
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import japanize_matplotlib
fig,ax = plt.subplots(1, figsize=(14,6))
# Out:
# (array([14610., 15340., 16071., 16801., 17532., 18262., 18993., 19723.,
#         20454.]),
#  [Text(14610.0, 0, '2010'),
#   Text(15340.0, 0, '2012'),
#   Text(16071.0, 0, '2014'),
#   Text(16801.0, 0, '2016'),
#   Text(17532.0, 0, '2018'),
#   Text(18262.0, 0, '2020'),
#   Text(18993.0, 0, '2022'),
#   Text(19723.0, 0, '2024'),
#   Text(20454.0, 0, '2026')])
